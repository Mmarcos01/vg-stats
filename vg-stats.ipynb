# %%
import pandas as pd

# %%
df = pd.read_csv('vgsales.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
df.head(5)
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
# Which company is the most common video game publisher?
df.Publisher.mode()
# Out:
# 0    Electronic Arts
# dtype: object

# %%
n = 3
df['Genre'].value_counts()[:n].index.tolist()
# Out:
# ['Action', 'Sports', 'Misc']

# %%
# What’s the most common platform?
df.Platform.mode()
# Out:
# 0    DS
# dtype: object

# %%
# What about the most common genre?
df.Genre.mode()
# Out:
# 0    Action
# dtype: object

# %%
# What are the top 20 highest grossing games?
rank = df[['Name', 'Global_Sales']]
rank.head(20)
# Out:
#                                             Name  Global_Sales
# 0                                     Wii Sports         82.74
# 1                              Super Mario Bros.         40.24
# 2                                 Mario Kart Wii         35.82
# 3                              Wii Sports Resort         33.00
# 4                       Pokemon Red/Pokemon Blue         31.37
# 5                                         Tetris         30.26
# 6                          New Super Mario Bros.         30.01
# 7                                       Wii Play         29.02
# 8                      New Super Mario Bros. Wii         28.62
# 9                                      Duck Hunt         28.31
# 10                                    Nintendogs         24.76
# 11                                 Mario Kart DS         23.42
# 12                   Pokemon Gold/Pokemon Silver         23.10
# 13                                       Wii Fit         22.72
# ...

# %%
# For North American video game sales, what’s the median?
df['NA_Sales'].median()
# Out:
# 0.08

# %%
# Provide a secondary output showing ten games surrounding the median sales output

median_sales = df['Global_Sales'].median()
df.iloc[(df['Global_Sales']-median_sales).abs().argsort()[:11]]
# Out:
#       Rank                                     Name Platform    Year  \
# 8298  8300   The Lord of the Rings: Aragorn's Quest      PS3  2010.0
# 8313  8315                              Backbreaker      PS3     NaN
# 8312  8314           Pursuit Force: Extreme Justice      PSP  2007.0
# 8311  8313  Jillian Michaels Fitness Ultimatum 2011      Wii  2010.0
# 8310  8312            Cabela's Legendary Adventures      PSP  2008.0
# 8309  8311                Macross Ultimate Frontier      PSP  2009.0
# 8308  8310            Tak: The Great Juju Challenge      GBA  2005.0
# 8307  8309             Looney Tunes: Back in Action       GC  2003.0
# 8306  8308    Super Robot Taisen Compact 2 Dai-1-Bu       WS  2000.0
# 8305  8307            Chuck E. Cheese's Party Games      Wii  2010.0
# 8304  8306            .hack//G.U. Vol.3//Redemption      PS2  2007.0
#
#              Genre                               Publisher  NA_Sales  \
# ...

# %%
# For the top-selling game of all time, how many standard deviations above/below the mean are its sales for North America?
# rank 1 NA - NA mean
df['NA_Sales'].mean()
# Out:
# 0.26466742981082064

# %%
df['NA_Sales'].std()
# Out:
# 0.8166830292988796

# %%
# The Nintendo Wii seems to have outdone itself with games. How does its average number of sales compare with all of the other platforms?
print('Wii average number of sales:', df[df['Platform'] == 'Wii']['Global_Sales'].mean())
print('All other platforms average number of sales:', df[df['Platform'] != 'Wii']['Global_Sales'].mean())
# Out:
# Wii average number of sales: 0.6994037735849057
# All other platforms average number of sales: 0.5233896418516336

# %%
# What is the lowest rank game? 
df['Name'].tail(1)
# Out:
# 16597    Spirits & Spells
# Name: Name, dtype: object

# %%
# Which year has the most games?

df.Year.mode()
# Out:
# 0    2009.0
# dtype: float64

# %%
#  What games fall under the year 2009?
df[df.Year == 2009.0]
# Out:
#         Rank                                  Name Platform    Year  \
# 3          4                     Wii Sports Resort      Wii  2009.0
# 8          9             New Super Mario Bros. Wii      Wii  2009.0
# 14        15                          Wii Fit Plus      Wii  2009.0
# 36        37        Call of Duty: Modern Warfare 2     X360  2009.0
# 45        46  Pokemon HeartGold/Pokemon SoulSilver       DS  2009.0
# ...      ...                                   ...      ...     ...
# 16540  16543                               15 Days       PC  2009.0
# 16551  16554                    Sweet Honey Coming      PS2  2009.0
# 16577  16580                             Damnation       PC  2009.0
# 16586  16589        Secret Files 2: Puritas Cordis       DS  2009.0
# 16587  16590              Mezase!! Tsuri Master DS       DS  2009.0
#
#            Genre          Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 3         Sports           Nintendo     15.75     11.01      3.28
# ...
